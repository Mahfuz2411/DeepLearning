# %% [markdown]
# # Parametric ReLU Activation Function

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define PReLU function
def prelu(x, a):  # 'a' is the learnable parameter (you can adjust it)
    return np.where(x > 0, x, a * x)

'''
We can do like this 
def prelu(x, a):
    if x > 0:
        return x
    else:
        return a * x
'''

# Generate input values
x = np.linspace(-10, 10, 100)
y = prelu(x, 0.1)

# Plot the PReLU function
plt.figure(figsize=(8, 4))
plt.plot(x, y, label='PReLU (a=0.1)', color='orange')
plt.title('PReLU Activation Function')
plt.xlabel('x')
plt.ylabel('PReLU(x)')
plt.grid(True)
plt.legend()
plt.show()
